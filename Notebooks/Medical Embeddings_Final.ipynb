# %% [markdown]
# # Medical Embeddings and clinical trial search engine

# %%
#  Importing Libraries

# %%
# pip install streamlit nltk gensim

# %%
import streamlit as st  #importing streamlit liabrary

# %%
# pip install --upgrade gensim scipy numpy

# %%
# pip install numpy==2.1.3

# %%
# pip install scipy==1.14.1

# %%
# pip install gensim==4.3.3

# %%
# pip install scipy

# %%
pip cache purge
# Out:
# Files removed: 2Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                                  Version
# ---------------------------------------- ------------
# absl-py                                  2.1.0
# aiohttp                                  3.9.5
# aiosignal                                1.3.1
# altair                                   5.4.1
# annotated-types                          0.6.0
# anyio                                    3.7.1
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# asgiref                                  3.8.1
# asttokens                                2.4.1
# astunparse                               1.6.3
# attrs                                    23.2.0
# audioread                                3.0.1
# backoff                                  2.2.1
# bcrypt                                   4.1.3
# beautifulsoup4                           4.12.3
# bleach                                   6.1.0
# blinker                                  1.9.0
# build                                    1.2.1
# cachetools                               5.3.3
# certifi                                  2024.2.2
# cffi                                     1.16.0
# chardet                                  5.2.0
# charset-normalizer                       3.3.2
# chroma-hnswlib                           0.7.3
# chromadb                                 0.5.0
# click                                    8.1.7
# click-plugins                            1.1.1
# cligj                                    0.7.2
# colorama                                 0.4.6
# coloredlogs                              15.0.1
# comm                                     0.2.1
# contourpy                                1.2.0
# cycler                                   0.12.1
# dataclasses-json                         0.6.6
# debugpy                                  1.8.0
# decorator                                5.1.1
# deepdiff                                 7.0.1
# defusedxml                               0.7.1
# Deprecated                               1.2.14
# distro                                   1.9.0
# dnspython                                2.6.1
# duckdb                                   0.10.0
# email_validator                          2.1.1
# emoji                                    2.11.1
# entrypoints                              0.4
# exceptiongroup                           1.2.0
# executing                                2.0.1
# fastapi                                  0.111.0
# fastapi-cli                              0.0.3
# fastjsonschema                           2.19.1
# filelock                                 3.14.0
# filetype                                 1.2.0
# fiona                                    1.9.5
# flatbuffers                              24.3.25
# fonttools                                4.49.0
# frozenlist                               1.4.1
# fsspec                                   2024.3.1
# gast                                     0.6.0
# gensim                                   4.3.3
# geopandas                                0.14.3
# gitdb                                    4.0.11
# GitPython                                3.1.43
# google-auth                              2.29.0
# google-pasta                             0.2.0
# googleapis-common-protos                 1.63.0
# greenlet                                 3.0.3
# grpcio                                   1.63.0
# h11                                      0.14.0
# h5py                                     3.11.0
# httpcore                                 1.0.5
# httptools                                0.6.1
# httpx                                    0.27.0
# huggingface-hub                          0.23.0
# humanfriendly                            10.0
# idna                                     3.6
# importlib-metadata                       7.0.0
# importlib-resources                      6.1.1
# intel-openmp                             2021.4.0
# ipykernel                                6.23.1
# ipython                                  8.19.0
# ipython-genutils                         0.2.0
# jedi                                     0.19.1
# Jinja2                                   3.1.3
# joblib                                   1.3.2
# jsonpatch                                1.33
# jsonpath-python                          1.0.6
# jsonpointer                              2.4
# jsonschema                               4.21.1
# jsonschema-specifications                2023.12.1
# jupyter_client                           8.6.0
# jupyter_core                             5.7.0
# jupyter-server                           1.24.0
# jupyterlab_pygments                      0.3.0
# keras                                    3.5.0
# kiwisolver                               1.4.5
# kneed                                    0.8.5
# kubernetes                               29.0.0
# langchain                                0.1.20
# langchain-community                      0.0.38
# langchain-core                           0.1.52
# langchain-text-splitters                 0.0.1
# langdetect                               1.0.9
# langsmith                                0.1.57
# lazy_loader                              0.4
# libclang                                 18.1.1
# librosa                                  0.10.2.post1
# llvmlite                                 0.42.0
# lxml                                     5.2.2
# Markdown                                 3.7
# markdown-it-py                           3.0.0
# MarkupSafe                               2.1.3
# marshmallow                              3.21.2
# matplotlib                               3.8.3
# matplotlib-inline                        0.1.6
# mdurl                                    0.1.2
# mistune                                  3.0.2
# mkl                                      2021.4.0
# mkl-fft                                  1.3.6
# mkl-random                               1.2.2
# mkl-service                              2.4.0
# ml-dtypes                                0.4.0
# mmh3                                     4.1.0
# monotonic                                1.6
# more-itertools                           10.2.0
# mpmath                                   1.3.0
# msgpack                                  1.0.8
# multidict                                6.0.5
# mypy-extensions                          1.0.0
# namex                                    0.0.8
# narwhals                                 1.13.5
# nbclassic                                1.0.0
# nbclient                                 0.8.0
# nbconvert                                7.15.0
# nbformat                                 5.9.2
# nest-asyncio                             1.5.8
# networkx                                 3.2.1
# nltk                                     3.8.1
# notebook                                 6.5.6
# notebook_shim                            0.2.3
# numba                                    0.59.0
# numexpr                                  2.10.0
# numpy                                    2.1.3
# oauthlib                                 3.2.2
# onnxruntime                              1.17.3
# openai                                   1.29.0
# openai-whisper                           20231117
# opentelemetry-api                        1.24.0
# opentelemetry-exporter-otlp-proto-common 1.24.0
# opentelemetry-exporter-otlp-proto-grpc   1.24.0
# opentelemetry-instrumentation            0.45b0
# opentelemetry-instrumentation-asgi       0.45b0
# opentelemetry-instrumentation-fastapi    0.45b0
# opentelemetry-proto                      1.24.0
# opentelemetry-sdk                        1.24.0
# opentelemetry-semantic-conventions       0.45b0
# opentelemetry-util-http                  0.45b0
# opt-einsum                               3.3.0
# optree                                   0.12.1
# ordered-set                              4.1.0
# orjson                                   3.10.3
# overrides                                7.7.0
# packaging                                23.2
# pandas                                   2.2.1
# pandocfilters                            1.5.0
# parso                                    0.8.3
# pickleshare                              0.7.5
# pillow                                   10.2.0
# pip                                      23.0.1
# pkgutil_resolve_name                     1.3.10
# platformdirs                             4.1.0
# plotly                                   5.19.0
# polars                                   0.20.13
# pooch                                    1.8.2
# posthog                                  3.5.0
# prometheus-client                        0.19.0
# prompt-toolkit                           3.0.43
# protobuf                                 4.25.3
# psutil                                   5.9.7
# pure-eval                                0.2.2
# pyarrow                                  15.0.0
# pyasn1                                   0.6.0
# pyasn1_modules                           0.4.0
# pycparser                                2.21
# pydantic                                 2.7.1
# pydantic_core                            2.18.2
# pydeck                                   0.9.1
# Pygments                                 2.17.2
# pynndescent                              0.5.11
# pyparsing                                3.1.1
# pypdf                                    4.2.0
# PyPika                                   0.48.9
# pyproj                                   3.6.1
# pyproject_hooks                          1.1.0
# pyreadline3                              3.4.1
# python-dateutil                          2.8.2
# python-dotenv                            1.0.1
# python-iso639                            2024.4.27
# python-magic                             0.4.27
# python-multipart                         0.0.9
# pytz                                     2024.1
# pywin32                                  306
# pywinpty                                 2.0.10
# PyYAML                                   6.0.1
# pyzmq                                    25.1.2
# rapidfuzz                                3.9.0
# referencing                              0.33.0
# regex                                    2024.5.10
# requests                                 2.31.0
# requests-oauthlib                        2.0.0
# rich                                     13.7.1
# rpds-py                                  0.10.6
# rsa                                      4.9
# safetensors                              0.4.3
# scikit-learn                             1.4.1.post1
# scipy                                    1.14.1
# seaborn                                  0.13.2
# Send2Trash                               1.8.2
# sentence-transformers                    2.7.0
# setuptools                               66.0.0
# shapely                                  2.0.3
# shellingham                              1.5.4
# six                                      1.16.0
# smart-open                               7.0.5
# smmap                                    5.0.1
# sniffio                                  1.3.0
# soundfile                                0.12.1
# soupsieve                                2.5
# soxr                                     0.5.0.post1
# SQLAlchemy                               2.0.30
# stack-data                               0.6.3
# starlette                                0.37.2
# streamlit                                1.40.1
# sympy                                    1.12
# tabulate                                 0.9.0
# tbb                                      2021.12.0
# tenacity                                 8.2.3
# tensorboard                              2.17.1
# tensorboard-data-server                  0.7.2
# tensorflow                               2.17.0
# tensorflow-intel                         2.17.0
# tensorflow-io-gcs-filesystem             0.31.0
# termcolor                                2.4.0
# terminado                                0.18.0
# threadpoolctl                            3.3.0
# tiktoken                                 0.7.0
# tinycss2                                 1.2.1
# tokenizers                               0.19.1
# toml                                     0.10.2
# torch                                    2.3.0
# tornado                                  6.4
# tqdm                                     4.66.2
# traitlets                                5.14.1
# transformers                             4.40.2
# typer                                    0.12.3
# typing_extensions                        4.12.2
# typing-inspect                           0.9.0
# tzdata                                   2024.1
# ujson                                    5.10.0
# umap                                     0.1.1
# umap-learn                               0.5.5
# unstructured                             0.13.7
# unstructured-client                      0.22.0
# urllib3                                  2.2.1
# uvicorn                                  0.29.0
# watchdog                                 6.0.0
# watchfiles                               0.21.0
# wcwidth                                  0.2.13
# webencodings                             0.5.1
# websocket-client                         1.7.0
# websockets                               12.0
# Werkzeug                                 3.0.4
# wheel                                    0.38.4
# wordcloud                                1.9.4
# wrapt                                    1.16.0
# yarl                                     1.9.4
# yellowbrick                              1.5
# zipp                                     3.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/15.8 MB 5.6 MB/s eta 0:00:03
#      -- ------------------------------------- 0.9/15.8 MB 9.8 MB/s eta 0:00:02
#      --- ------------------------------------ 1.6/15.8 MB 11.2 MB/s eta 0:00:02
#      ----- ---------------------------------- 2.3/15.8 MB 13.4 MB/s eta 0:00:02
#      -------- ------------------------------- 3.5/15.8 MB 15.9 MB/s eta 0:00:01
#      ------------ --------------------------- 4.8/15.8 MB 18.2 MB/s eta 0:00:01
#      --------------- ------------------------ 5.9/15.8 MB 19.0 MB/s eta 0:00:01
#      ------------------- -------------------- 7.6/15.8 MB 21.1 MB/s eta 0:00:01
#      ---------------------- ----------------- 9.0/15.8 MB 22.1 MB/s eta 0:00:01
#      ------------------------- ------------- 10.5/15.8 MB 24.2 MB/s eta 0:00:01
#      ---------------------------- ---------- 11.8/15.8 MB 27.3 MB/s eta 0:00:01
#      ------------------------------- ------- 12.7/15.8 MB 28.5 MB/s eta 0:00:01
#      ----------------------------------- --- 14.2/15.8 MB 28.5 MB/s eta 0:00:01
#      --------------------------------------  15.7/15.8 MB 28.5 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 28.4 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 28.4 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 28.4 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 28.4 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 28.4 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 28.4 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 28.4 MB/s eta 0:00:01
#      --------------------------------------- 15.8/15.8 MB 14.5 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\HP\\Documents\\Anaconda\\envs\\shola\\Lib\\site-packages\\~-mpy.libs\\libscipy_openblas64_-c16e4918366c6bc1f1cd71e28ca36fc0.dll'
# Consider using the `--user` option or check the permissions.

# %%
pip install --upgrade pandas numpy
# Out:
# Requirement already satisfied: pandas in c:\users\hp\documents\anaconda\lib\site-packages (2.2.0)
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy in c:\users\hp\documents\anaconda\lib\site-packages (1.26.4)
# Collecting numpy
#   Downloading numpy-2.1.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\documents\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\documents\anaconda\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\documents\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\documents\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ------- -------------------------------- 2.1/11.6 MB 11.8 MB/s eta 0:00:01
#    ------------------ --------------------- 5.2/11.6 MB 13.9 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.6 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 16.5 MB/s eta 0:00:00
# Downloading numpy-2.1.3-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ----------------- ---------------------- 5.8/12.9 MB 27.1 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.9 MB 25.8 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 24.4 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 24.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 13.9 MB/s eta 0:00:00
# Installing collected packages: numpy, pandas
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Rolling back uninstall of numpy
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy-1.26.4-cp310-cp310-win_amd64.whl
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy-1.26.4-cp310-cp310-win_amd64.whl
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy-1.26.4.dist-info\
#    from C:\Users\HP\Documents\Anaconda\Lib\site-packages\~umpy-1.26.4.dist-info
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy.libs\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy.libs\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__config__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__config__.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__init__.cython-30.pxd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__init__.cython-30.pxd
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__init__.pxd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__init__.pxd
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__init__.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__init__.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__init__.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__pycache__\__config__.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__pycache__\__config__.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__pycache__\_distributor_init.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__pycache__\_distributor_init.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__pycache__\_globals.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__pycache__\_globals.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__pycache__\_pytesttester.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__pycache__\_pytesttester.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__pycache__\conftest.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__pycache__\conftest.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__pycache__\ctypeslib.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__pycache__\ctypeslib.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__pycache__\dtypes.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__pycache__\dtypes.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__pycache__\exceptions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__pycache__\exceptions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__pycache__\matlib.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__pycache__\matlib.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\__pycache__\version.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\__pycache__\version.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\__init__.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\__init__.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\__init__.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\__pycache__\_dtype.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\__pycache__\_dtype.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\__pycache__\_dtype_ctypes.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\__pycache__\_dtype_ctypes.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\__pycache__\_internal.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\__pycache__\_internal.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\__pycache__\_multiarray_umath.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\__pycache__\_multiarray_umath.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\__pycache__\multiarray.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\__pycache__\multiarray.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\__pycache__\umath.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\__pycache__\umath.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\_dtype.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\_dtype.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\_dtype_ctypes.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\_dtype_ctypes.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\_internal.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\_internal.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\_multiarray_umath.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\_multiarray_umath.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\multiarray.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\multiarray.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_core\umath.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_core\umath.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_distributor_init.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_distributor_init.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_globals.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_globals.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_pyinstaller\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_pyinstaller\__init__.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_pyinstaller\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_pyinstaller\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_pyinstaller\__pycache__\hook-numpy.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_pyinstaller\__pycache__\hook-numpy.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_pyinstaller\__pycache__\pyinstaller-smoke.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_pyinstaller\__pycache__\pyinstaller-smoke.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_pyinstaller\__pycache__\test_pyinstaller.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_pyinstaller\__pycache__\test_pyinstaller.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_pyinstaller\hook-numpy.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_pyinstaller\hook-numpy.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_pyinstaller\pyinstaller-smoke.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_pyinstaller\pyinstaller-smoke.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_pyinstaller\test_pyinstaller.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_pyinstaller\test_pyinstaller.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_pytesttester.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_pytesttester.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_pytesttester.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_pytesttester.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\__init__.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\__pycache__\_add_docstring.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\__pycache__\_add_docstring.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\__pycache__\_array_like.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\__pycache__\_array_like.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\__pycache__\_char_codes.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\__pycache__\_char_codes.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\__pycache__\_dtype_like.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\__pycache__\_dtype_like.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\__pycache__\_extended_precision.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\__pycache__\_extended_precision.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\__pycache__\_nbit.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\__pycache__\_nbit.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\__pycache__\_nested_sequence.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\__pycache__\_nested_sequence.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\__pycache__\_scalars.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\__pycache__\_scalars.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\__pycache__\_shape.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\__pycache__\_shape.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\__pycache__\setup.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\__pycache__\setup.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\_add_docstring.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\_add_docstring.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\_array_like.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\_array_like.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\_callable.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\_callable.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\_char_codes.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\_char_codes.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\_dtype_like.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\_dtype_like.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\_extended_precision.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\_extended_precision.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\_nbit.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\_nbit.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\_nested_sequence.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\_nested_sequence.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\_scalars.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\_scalars.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\_shape.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\_shape.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\_ufunc.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\_ufunc.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_typing\setup.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_typing\setup.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_utils\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_utils\__init__.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_utils\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_utils\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_utils\__pycache__\_convertions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_utils\__pycache__\_convertions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_utils\__pycache__\_inspect.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_utils\__pycache__\_inspect.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_utils\__pycache__\_pep440.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_utils\__pycache__\_pep440.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_utils\_convertions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_utils\_convertions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_utils\_inspect.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_utils\_inspect.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\_utils\_pep440.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\_utils\_pep440.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__init__.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_array_object.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_array_object.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_constants.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_constants.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_creation_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_creation_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_data_type_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_data_type_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_dtypes.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_dtypes.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_elementwise_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_elementwise_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_indexing_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_indexing_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_manipulation_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_manipulation_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_searching_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_searching_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_set_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_set_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_sorting_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_sorting_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_statistical_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_statistical_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_typing.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_typing.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\_utility_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\_utility_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\linalg.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\linalg.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\__pycache__\setup.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\__pycache__\setup.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_array_object.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_array_object.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_constants.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_constants.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_creation_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_creation_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_data_type_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_data_type_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_dtypes.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_dtypes.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_elementwise_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_elementwise_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_indexing_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_indexing_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_manipulation_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_manipulation_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_searching_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_searching_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_set_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_set_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_sorting_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_sorting_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_statistical_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_statistical_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_typing.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_typing.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\_utility_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\_utility_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\linalg.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\linalg.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\setup.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\setup.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\__init__.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\__pycache__\test_array_object.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\__pycache__\test_array_object.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\__pycache__\test_creation_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\__pycache__\test_creation_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\__pycache__\test_data_type_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\__pycache__\test_data_type_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\__pycache__\test_elementwise_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\__pycache__\test_elementwise_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\__pycache__\test_indexing_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\__pycache__\test_indexing_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\__pycache__\test_manipulation_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\__pycache__\test_manipulation_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\__pycache__\test_set_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\__pycache__\test_set_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\__pycache__\test_sorting_functions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\__pycache__\test_sorting_functions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\__pycache__\test_validation.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\__pycache__\test_validation.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\test_array_object.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\test_array_object.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\test_creation_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\test_creation_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\test_data_type_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\test_data_type_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\test_elementwise_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\test_elementwise_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\test_indexing_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\test_indexing_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\test_manipulation_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\test_manipulation_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\test_set_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\test_set_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\test_sorting_functions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\test_sorting_functions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\array_api\tests\test_validation.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\array_api\tests\test_validation.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\compat\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\compat\__init__.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\compat\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\compat\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\compat\__pycache__\py3k.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\compat\__pycache__\py3k.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\compat\__pycache__\setup.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\compat\__pycache__\setup.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\compat\py3k.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\compat\py3k.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\compat\setup.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\compat\setup.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\compat\tests\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\compat\tests\__init__.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\compat\tests\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\compat\tests\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\compat\tests\__pycache__\test_compat.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\compat\tests\__pycache__\test_compat.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\compat\tests\test_compat.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\compat\tests\test_compat.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\conftest.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\conftest.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__init__.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__init__.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__init__.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__init__.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\_add_newdocs.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\_add_newdocs.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\_add_newdocs_scalars.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\_add_newdocs_scalars.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\_asarray.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\_asarray.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\_dtype.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\_dtype.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\_dtype_ctypes.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\_dtype_ctypes.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\_exceptions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\_exceptions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\_internal.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\_internal.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\_machar.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\_machar.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\_methods.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\_methods.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\_string_helpers.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\_string_helpers.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\_type_aliases.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\_type_aliases.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\_ufunc_config.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\_ufunc_config.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\arrayprint.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\arrayprint.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\cversions.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\cversions.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\defchararray.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\defchararray.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\einsumfunc.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\einsumfunc.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\fromnumeric.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\fromnumeric.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\function_base.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\function_base.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\getlimits.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\getlimits.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\memmap.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\memmap.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\multiarray.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\multiarray.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\numeric.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\numeric.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\numerictypes.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\numerictypes.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\overrides.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\overrides.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\records.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\records.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\shape_base.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\shape_base.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\umath.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\umath.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\__pycache__\umath_tests.cpython-310.pyc
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\__pycache__\umath_tests.cpython-310.pyc
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_add_newdocs.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_add_newdocs.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_add_newdocs_scalars.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_add_newdocs_scalars.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_asarray.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_asarray.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_asarray.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_asarray.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_dtype.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_dtype.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_dtype_ctypes.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_dtype_ctypes.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_exceptions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_exceptions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_internal.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_internal.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_internal.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_internal.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_machar.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_machar.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_methods.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_methods.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_multiarray_tests.cp310-win_amd64.lib
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_multiarray_tests.cp310-win_amd64.lib
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_multiarray_tests.cp310-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_multiarray_tests.cp310-win_amd64.pyd
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_multiarray_umath.cp310-win_amd64.lib
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_multiarray_umath.cp310-win_amd64.lib
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_multiarray_umath.cp310-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_multiarray_umath.cp310-win_amd64.pyd
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_operand_flag_tests.cp310-win_amd64.lib
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_operand_flag_tests.cp310-win_amd64.lib
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_operand_flag_tests.cp310-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_operand_flag_tests.cp310-win_amd64.pyd
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_rational_tests.cp310-win_amd64.lib
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_rational_tests.cp310-win_amd64.lib
# Note: you may need to restart the kernel to use updated packages.
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_rational_tests.cp310-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_rational_tests.cp310-win_amd64.pyd
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_simd.cp310-win_amd64.lib
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_simd.cp310-win_amd64.lib
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_simd.cp310-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_simd.cp310-win_amd64.pyd
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_string_helpers.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_string_helpers.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_struct_ufunc_tests.cp310-win_amd64.lib
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_struct_ufunc_tests.cp310-win_amd64.lib
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_struct_ufunc_tests.cp310-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_struct_ufunc_tests.cp310-win_amd64.pyd
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_type_aliases.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_type_aliases.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_type_aliases.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_type_aliases.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_ufunc_config.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_ufunc_config.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_ufunc_config.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_ufunc_config.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_umath_tests.cp310-win_amd64.lib
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_umath_tests.cp310-win_amd64.lib
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\_umath_tests.cp310-win_amd64.pyd
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\_umath_tests.cp310-win_amd64.pyd
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\arrayprint.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\arrayprint.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\arrayprint.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\arrayprint.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\cversions.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\cversions.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\defchararray.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\defchararray.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\defchararray.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\defchararray.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\einsumfunc.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\einsumfunc.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\einsumfunc.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\einsumfunc.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\fromnumeric.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\fromnumeric.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\fromnumeric.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\fromnumeric.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\function_base.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\function_base.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\function_base.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\function_base.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\getlimits.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\getlimits.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\getlimits.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\getlimits.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\include\numpy\
#    from C:\Users\HP\Documents\Anaconda\Lib\site-packages\numpy\core\include\~umpy
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\lib\
#    from C:\Users\HP\Documents\Anaconda\Lib\site-packages\numpy\core\~ib
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\memmap.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\memmap.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\memmap.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\memmap.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\core\multiarray.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\core\multiarray.py
# ...
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\modules.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\multiarray.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\multiarray.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\ndarray_conversion.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\ndarray_conversion.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\ndarray_misc.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\ndarray_misc.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\ndarray_shape_manipulation.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\ndarray_shape_manipulation.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\numeric.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\numeric.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\numerictypes.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\numerictypes.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\random.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\random.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\scalars.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\scalars.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\simple.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\simple.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\simple_py3.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\simple_py3.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\ufunc_config.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\ufunc_config.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\ufunclike.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\ufunclike.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\ufuncs.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\ufuncs.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\pass\warnings_and_errors.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\pass\warnings_and_errors.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\arithmetic.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\arithmetic.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\array_constructors.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\array_constructors.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\arraypad.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\arraypad.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\arrayprint.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\arrayprint.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\arraysetops.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\arraysetops.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\arrayterator.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\arrayterator.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\bitwise_ops.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\bitwise_ops.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\char.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\char.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\chararray.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\chararray.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\comparisons.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\comparisons.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\constants.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\constants.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\ctypeslib.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\ctypeslib.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\datasource.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\datasource.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\dtype.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\dtype.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\einsumfunc.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\einsumfunc.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\emath.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\emath.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\false_positives.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\false_positives.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\fft.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\fft.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\flatiter.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\flatiter.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\fromnumeric.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\fromnumeric.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\getlimits.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\getlimits.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\histograms.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\histograms.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\index_tricks.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\index_tricks.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\lib_function_base.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\lib_function_base.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\lib_polynomial.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\lib_polynomial.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\lib_utils.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\lib_utils.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\lib_version.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\lib_version.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\linalg.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\linalg.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\matrix.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\matrix.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\memmap.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\memmap.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\mod.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\mod.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\modules.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\modules.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\multiarray.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\multiarray.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\nbit_base_example.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\nbit_base_example.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\ndarray_conversion.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\ndarray_conversion.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\ndarray_misc.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\ndarray_misc.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\ndarray_shape_manipulation.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\ndarray_shape_manipulation.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\nditer.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\nditer.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\nested_sequence.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\nested_sequence.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\npyio.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\npyio.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\numeric.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\numeric.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\numerictypes.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\numerictypes.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\random.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\random.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\rec.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\rec.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\scalars.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\scalars.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\shape_base.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\shape_base.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\stride_tricks.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\stride_tricks.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\testing.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\testing.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\twodim_base.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\twodim_base.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\type_check.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\type_check.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\ufunc_config.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\ufunc_config.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\ufunclike.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\ufunclike.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\ufuncs.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\ufuncs.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\data\reveal\warnings_and_errors.pyi
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\data\reveal\warnings_and_errors.pyi
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\test_isfile.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\test_isfile.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\test_runtime.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\test_runtime.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\typing\tests\test_typing.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\typing\tests\test_typing.py
#   Moving to c:\users\hp\documents\anaconda\lib\site-packages\numpy\version.py
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-4wq17kxe\numpy\version.py
#   Moving to c:\users\hp\documents\anaconda\scripts\f2py.exe
#    from C:\Users\HP\AppData\Local\Temp\pip-uninstall-_ku1ofcr\f2py.exe
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\documents\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\documents\anaconda\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\HP\\Documents\\Anaconda\\Lib\\site-packages\\numpy\\_core\\_multiarray_umath.cp310-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
from scipy.stats import entropy
print(entropy([0.1, 0.9]))
# Out:
# 0.3250829733914482

# %%
import numpy as np
import pandas as pd
import pyarrow as pa

print(np.__version__)
print(pd.__version__)
print(pa.__version__)
# Out:
# 1.26.4
# 2.2.3
# 15.0.0

# %%
import pandas as pd
import numpy as np
import gensim
from gensim.models import Word2Vec
from gensim.models import FastText
from sklearn.decomposition import PCA
from matplotlib import pyplot

# %%
import matplotlib.pyplot as plt # our main display package
import plotly.graph_objects as go
import string # used for preprocessing
import re # used for preprocessing
import nltk # the Natural Language Toolkit, used for preprocessing
import numpy as np # used for managing NaNs
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords # used for preprocessing
from nltk.stem import WordNetLemmatizer # used for preprocessing
from sklearn.model_selection import train_test_split
nltk.download('stopwords', download_dir='C:\\Users\\HP/nltk_data')
nltk.download('wordnet', download_dir='C:\\Users\\HP/nltk_data')
nltk.download('punkt', download_dir='C:\\Users\\HP/nltk_data')
# matplotlib.use('TkAgg')  # Use an interactive backend
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\HP/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\HP/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\HP/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Importing datasets

# %%
df=pd.read_csv('Dimension-covid.csv')   #for preprocessing
df1=pd.read_csv('Dimension-covid.csv')  #for returning results

# %% [markdown]
# # Preprocessing data

# %%
df.shape
# Out:
# (10666, 21)

# %%
df.head()
# Out:
#    Date added     Trial ID                                              Title  \
# 0  2021-06-04  NCT04912934  The Relationship Between Coronavirus Anxiety L...
# 1  2021-06-04  NCT04912921  Effect of Palmitoylethanolamide on Proinflamma...
# 2  2021-06-04  NCT04912895  Detection of SARS-CoV-2 RNA and Biomarkers in ...
# 3  2021-06-04  NCT04912817  Pain Rehabilitation Virtual Reality (PR-VR) At...
# 4  2021-06-04  NCT04912804  Perceived Health After Hospitalization for COV...
#
#                                          Brief title    Acronym  \
# 0  The Relationship Between COVID-19 Anxiety Leve...   COVID-19
# 1  Effect of Palmitoylethanolamide on Proinflamma...        NaN
# 2  Detection of SARS-CoV-2 RNA in Coughed Droplet...        NaN
# 3    PR-VR At-home Program During and After COVID-19        NaN
# 4  Perceived Health After Hospitalization for COV...  PRO-COVID
#
#                                             Abstract Publication date  \
# 0  The aim was to determine the coronavirus anxie...       2020-06-20
# 1  This is a randomized controlled trial to exami...       2020-10-20
# 2  The purpose of this study is to learn how to b...       2021-04-14
# 3  Poorly controlled chronic pain in teens can im...       2021-09-01
# 4  There are currently no precise data available ...       2020-06-30
#
#        Active years Phase                                      Conditions  \
# 0              2020   NaN  COVID-19; Emotional Eating; Metabolic Syndrome
# 1  2020; 2021; 2022   NaN                           COVID19; Inflammation
# 2        2021; 2022   NaN                                         Covid19
# 3        2021; 2022   NaN                                   Pain, Chronic
# 4        2020; 2021   NaN  COVID-19, Post-hospitalization, Disease Impact
#
#    ... Gender            Registry Investigators/Contacts  \
# 0  ...    All  ClinicalTrials.gov    Dilek Küçük Alemdar
# 1  ...    All  ClinicalTrials.gov                    NaN
# 2  ...    All  ClinicalTrials.gov         Larry Anderson
# 3  ...    All  ClinicalTrials.gov       Jennifer Stinson
# 4  ...    All  ClinicalTrials.gov                    NaN
#
#                               Sponsors/Collaborators  \
# 0                                    Ordu University
# 1                           Arizona State University
# 2  Emory University Hospital Midtown; Emory Unive...
# 3    Hospital for Sick Children; Stanford University
# 4   Centre Hospitalier Universitaire Dijon Bourgogne
#
#                                             GRID IDs  \
# 0                                      grid.412366.4
# 1                                      grid.215654.1
# 2  grid.411929.6; grid.412162.2; grid.189967.8; g...
# 3                       grid.42327.30; grid.168010.e
# 4                                      grid.31151.37
#
#                      Country of Sponsor/Collaborator  \
# 0                                             Turkey
# 1                                      United States
# 2  United States; United States; United States; U...
# 3                              Canada; United States
# 4                                             France
#
#         Collaborating Funders Funder Country  \
# 0                         NaN            NaN
# 1                         NaN            NaN
# 2                         NaN            NaN
# 3  Hospital for Sick Children         Canada
# 4                         NaN            NaN
#
#                                 Source Linkout  \
# 0  https://clinicaltrials.gov/show/NCT04912934
# 1  https://clinicaltrials.gov/show/NCT04912921
# 2  https://clinicaltrials.gov/show/NCT04912895
# 3  https://clinicaltrials.gov/show/NCT04912817
# 4  https://clinicaltrials.gov/show/NCT04912804
#
#                                       Dimensions URL
# 0  https://app.dimensions.ai/details/clinical_tri...
# 1  https://app.dimensions.ai/details/clinical_tri...
# 2  https://app.dimensions.ai/details/clinical_tri...
# 3  https://app.dimensions.ai/details/clinical_tri...
# 4  https://app.dimensions.ai/details/clinical_tri...
#
# [5 rows x 21 columns]

# %%
df['Abstract'][0]
# Out:
# 'The aim was to determine the coronavirus anxiety levels and emotional eating status of cases with diagnosis of MetS according to diagnostic criteria published by the International Diabetic Federation (IDF) in 2005 and healthy individuals with similar BMI to MetS subjects.\n\nDetailed Description\nThe aim was to determine the coronavirus anxiety levels and emotional eating status of cases with diagnosis of MetS according to diagnostic criteria published by the International Diabetic Federation (IDF) in 2005 and healthy individuals with similar BMI to MetS subjects. This study was completed with the descriptive, cross-sectional and relational screening model. The full sampling method was used in the study. The study was completed with 105 individuals with metabolic syndrome attending the diet clinic and 109 healthy individuals without MetS diagnosis also attending the diet clinic. Collection of data used anthropometric measurements and biochemical findings, blood pressure and a survey form, the Coronavirus Anxiety Scale (CAS) and Emotional Eating Scale (EES).'

# %% [markdown]
# ### Defining Functions

# %%
# function to remove all urls
def remove_urls(text):    
    new_text = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text).split())
    return new_text

# make all text lowercase
def text_lowercase(text):
    return text.lower()

# remove numbers
def remove_numbers(text):
    result = re.sub(r'\d+', '', text)
    return result

# remove punctuation
def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

# tokenize
def tokenize(text):
    text = word_tokenize(text)
    return text

# remove stopwords
stop_words = set(stopwords.words('english'))
def remove_stopwords(text):
    text = [i for i in text if not i in stop_words]
    return text

# lemmatize Words 
lemmatizer = WordNetLemmatizer()
def lemmatize(text):
    text = [lemmatizer.lemmatize(token) for token in text]
    return text

# %%
# Unifying all functions into one so they can be applied at once
def preprocessing(text):
    
    text = text_lowercase(text)
    text = remove_urls(text)
    text = remove_numbers(text)
    text = remove_punctuation(text)
    text = tokenize(text)
    text = remove_stopwords(text)
    text = lemmatize(text)
    text = ' '.join(text)
    return text

# %%
from nltk.tokenize import word_tokenize

text = "This is a sample sentence for testing."
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', 'for', 'testing', '.']

# %%
#Applying preprocessing and removing '\n' character

for i in range(df.shape[0]):
    df['Abstract'][i]=preprocessing(str(df['Abstract'][i])) 
for text in df.Abstract:

    text=text.replace('\n',' ')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11976\1388839593.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Abstract'][i]=preprocessing(str(df['Abstract'][i]))

# %%
df.head()
# Out:
#    Date added     Trial ID                                              Title  \
# 0  2021-06-04  NCT04912934  The Relationship Between Coronavirus Anxiety L...
# 1  2021-06-04  NCT04912921  Effect of Palmitoylethanolamide on Proinflamma...
# 2  2021-06-04  NCT04912895  Detection of SARS-CoV-2 RNA and Biomarkers in ...
# 3  2021-06-04  NCT04912817  Pain Rehabilitation Virtual Reality (PR-VR) At...
# 4  2021-06-04  NCT04912804  Perceived Health After Hospitalization for COV...
#
#                                          Brief title    Acronym  \
# 0  The Relationship Between COVID-19 Anxiety Leve...   COVID-19
# 1  Effect of Palmitoylethanolamide on Proinflamma...        NaN
# 2  Detection of SARS-CoV-2 RNA in Coughed Droplet...        NaN
# 3    PR-VR At-home Program During and After COVID-19        NaN
# 4  Perceived Health After Hospitalization for COV...  PRO-COVID
#
#                                             Abstract Publication date  \
# 0  aim determine coronavirus anxiety level emotio...       2020-06-20
# 1  randomized controlled trial examine effect foo...       2020-10-20
# 2  purpose study learn better detect infection un...       2021-04-14
# 3  poorly controlled chronic pain teen impact qua...       2021-09-01
# 4  currently precise data available impact covid ...       2020-06-30
#
#        Active years Phase                                      Conditions  \
# 0              2020   NaN  COVID-19; Emotional Eating; Metabolic Syndrome
# 1  2020; 2021; 2022   NaN                           COVID19; Inflammation
# 2        2021; 2022   NaN                                         Covid19
# 3        2021; 2022   NaN                                   Pain, Chronic
# 4        2020; 2021   NaN  COVID-19, Post-hospitalization, Disease Impact
#
#    ... Gender            Registry Investigators/Contacts  \
# 0  ...    All  ClinicalTrials.gov    Dilek Küçük Alemdar
# 1  ...    All  ClinicalTrials.gov                    NaN
# 2  ...    All  ClinicalTrials.gov         Larry Anderson
# 3  ...    All  ClinicalTrials.gov       Jennifer Stinson
# 4  ...    All  ClinicalTrials.gov                    NaN
#
#                               Sponsors/Collaborators  \
# 0                                    Ordu University
# 1                           Arizona State University
# 2  Emory University Hospital Midtown; Emory Unive...
# 3    Hospital for Sick Children; Stanford University
# 4   Centre Hospitalier Universitaire Dijon Bourgogne
#
#                                             GRID IDs  \
# 0                                      grid.412366.4
# 1                                      grid.215654.1
# 2  grid.411929.6; grid.412162.2; grid.189967.8; g...
# 3                       grid.42327.30; grid.168010.e
# 4                                      grid.31151.37
#
#                      Country of Sponsor/Collaborator  \
# 0                                             Turkey
# 1                                      United States
# 2  United States; United States; United States; U...
# 3                              Canada; United States
# 4                                             France
#
#         Collaborating Funders Funder Country  \
# 0                         NaN            NaN
# 1                         NaN            NaN
# 2                         NaN            NaN
# 3  Hospital for Sick Children         Canada
# 4                         NaN            NaN
#
#                                 Source Linkout  \
# 0  https://clinicaltrials.gov/show/NCT04912934
# 1  https://clinicaltrials.gov/show/NCT04912921
# 2  https://clinicaltrials.gov/show/NCT04912895
# 3  https://clinicaltrials.gov/show/NCT04912817
# 4  https://clinicaltrials.gov/show/NCT04912804
#
#                                       Dimensions URL
# 0  https://app.dimensions.ai/details/clinical_tri...
# 1  https://app.dimensions.ai/details/clinical_tri...
# 2  https://app.dimensions.ai/details/clinical_tri...
# 3  https://app.dimensions.ai/details/clinical_tri...
# 4  https://app.dimensions.ai/details/clinical_tri...
#
# [5 rows x 21 columns]

# %%
df['Abstract'][0]
# Out:
# 'aim determine coronavirus anxiety level emotional eating status case diagnosis mets according diagnostic criterion published international diabetic federation idf healthy individual similar bmi mets subject detailed description aim determine coronavirus anxiety level emotional eating status case diagnosis mets according diagnostic criterion published international diabetic federation idf healthy individual similar bmi mets subject study completed descriptive cross sectional relational screening model full sampling method used study study completed individual metabolic syndrome attending diet clinic healthy individual without mets diagnosis also attending diet clinic collection data used anthropometric measurement biochemical finding blood pressure survey form coronavirus anxiety scale ca emotional eating scale ee'

# %%
#Applying preprocessing and removing '\n' character

for i in range(df.shape[0]):
    df['Title'][i]=preprocessing(str(df['Title'][i])) 
for text in df.Title:

    text=text.replace('\n',' ')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11976\744592391.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Title'][i]=preprocessing(str(df['Title'][i]))

# %%
x=[word_tokenize(word) for word in df.Abstract ]   #Tokenizing data for training purpose

# %% [markdown]
# # Exploratory data analysis

# %%
from collections import Counter
cnt = Counter()
for text in df["Abstract"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(10)  #top 10 common words
# Out:
# [('patient', 38457),
#  ('covid', 38211),
#  ('study', 31963),
#  ('group', 12771),
#  ('treatment', 12471),
#  ('day', 12337),
#  ('sars', 11600),
#  ('cov', 11535),
#  ('clinical', 11507),
#  ('disease', 11395)]

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\hp\documents\anaconda\envs\shola\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\hp\documents\anaconda\envs\shola\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\hp\documents\anaconda\envs\shola\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\hp\documents\anaconda\envs\shola\lib\site-packages (from wordcloud) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\documents\anaconda\envs\shola\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\documents\anaconda\envs\shola\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\documents\anaconda\envs\shola\lib\site-packages (from matplotlib->wordcloud) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\documents\anaconda\envs\shola\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\documents\anaconda\envs\shola\lib\site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
#Final word cloud after all the cleaning and pre-processing
from wordcloud import WordCloud
from textwrap import wrap
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
#comment_words = ' '
stopwords = set(STOPWORDS) 
from pandas.core.common import flatten

# iterate through the csv file 


comment_words=flatten(x)
comment_words=' '.join(comment_words)


wordcloud = WordCloud(width = 800, height = 800, 
            background_color ='white', 
            stopwords = stopwords, 
            min_font_size = 10).generate(comment_words) 

# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.show() 
wordcloud.to_file("wordcloud.png")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_35380\4119911032.py:28: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# # Training skipgram model

# %%
# training the model

skipgram = Word2Vec(x, vector_size =50, window = 3, min_count=2,sg = 1)
print(skipgram)
skipgram.save('skipgramx1.bin')
# Out:
# Word2Vec<vocab=24877, vector_size=50, alpha=0.025>

# %%
# training the model

skipgram = Word2Vec(x, vector_size =100, window = 1, min_count=2,sg = 1)
print(skipgram)
skipgram.save('skipgramx11.bin')
# Out:
# Word2Vec<vocab=24877, vector_size=100, alpha=0.025>

# %%
# Loading the model
skipgram = Word2Vec.load('skipgramx11.bin')

# %% [markdown]
# # Training Fasttext model

# %%
fast_n= FastText(x,vector_size=200, window=3, min_count=2, workers=5, min_n=1, max_n=2,sg=1)  #training fasttext Model, with skipgram
fast_n=fast_n.save('fast_p.bin')    #Saving our model
fast_n = Word2Vec.load('fast_p.bin')  #Loading our pretrained model

# %%
FastText=FastText(x,vector_size=100, window=2, min_count=2, workers=5, min_n=1, max_n=2,sg=1)
FastText.save('FastText.bin')    #Saving our model
FastText = Word2Vec.load('FastText.bin')  #Loading our pretrained model

# %% [markdown]
# ## Model embeddings - Similarity

# %%
# Similar words - skipgram

skipgram.wv.most_similar(positive=['corona'],topn=10)
# Out:
# [('coronavirus', 0.7503097653388977),
#  ('covid', 0.7034178972244263),
#  ('evd', 0.6834739446640015),
#  ('novelty', 0.6830587387084961),
#  ('crown', 0.676692545413971),
#  ('ebola', 0.6725965738296509),
#  ('declares', 0.6633520722389221),
#  ('coronovirus', 0.6624356508255005),
#  ('betacoronavirus', 0.6613567471504211),
#  ('virulent', 0.661322832107544)]

# %%
skipgram.wv.most_similar(positive=['patient'],topn=10)
# Out:
# [('hospitalised', 0.7482302784919739),
#  ('subject', 0.7420821785926819),
#  ('acutely', 0.732924222946167),
#  ('participant', 0.7316153049468994),
#  ('individual', 0.7278432250022888),
#  ('moderately', 0.7222221493721008),
#  ('recovering', 0.7149496078491211),
#  ('survivor', 0.6993590593338013),
#  ('pwcf', 0.6945300102233887),
#  ('lymphocytopenia', 0.6935097575187683)]

# %%
# Similar words - fasttext

FastText.wv.most_similar(positive=['lung'],topn=10)
# Out:
# [('lungiq', 0.7419402003288269),
#  ('leung', 0.7163769006729126),
#  ('alveolus', 0.688120424747467),
#  ('silicovilung', 0.6789316534996033),
#  ('pulmonary', 0.6761114001274109),
#  ('volunteering', 0.6715412139892578),
#  ('ground', 0.6670790314674377),
#  ('laung', 0.6628875732421875),
#  ('lure', 0.6618518829345703),
#  ('library', 0.6538442969322205)]

# %%
FastText.wv.most_similar(positive=['breathing'],topn=10)
# Out:
# [('rebreathing', 0.9196434617042542),
#  ('breaching', 0.9106032252311707),
#  ('breathe', 0.8828759789466858),
#  ('bathing', 0.8640894293785095),
#  ('breath', 0.8583236932754517),
#  ('breathed', 0.8573281168937683),
#  ('breaking', 0.850764274597168),
#  ('breathable', 0.8393508195877075),
#  ('threatening', 0.8366652131080627),
#  ('babybreathe', 0.8299291729927063)]

# %% [markdown]
# # PCA Plot - Skipgram

# %%
X = skipgram.wv[skipgram.wv.index_to_key]    #storing arrays of all words
pca = PCA(n_components=2)                    #applying PCA to convert data into two dimensions
result = pca.fit_transform(X)

# %%
#words embeddings on the plot to check 2-D representation of each word
pyplot.scatter(result[:10, 0], result[:10, 1])
words = list(skipgram.wv.index_to_key)
for i, word in enumerate(words[:10]):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_35380\352274146.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   pyplot.show()

# %% [markdown]
# # PCA Plot - Fasttest

# %%
#same thing as above but with fasttext model
X_fast = FastText.wv[FastText.wv.index_to_key]
pca = PCA(n_components=2)
result_fast = pca.fit_transform(X_fast)

# %%
pyplot.scatter(result_fast[:10, 0], result_fast[:10, 1])
words = list(FastText.wv.index_to_key)
for i, word in enumerate(words[:10]):
    pyplot.annotate(word, xy=(result_fast[i, 0], result_fast[i, 1]))
pyplot.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_35380\178506286.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   pyplot.show()

# %% [markdown]
# # Getting Vectors for each abstract

# %%
vector_size=100   #defining vector size for each word

# %% [markdown]
# ### Method 1

# %%
#function to take average of all vectors of each word in abstract, so that each abstract can represent (1,100) dimensional vector

K1=[]      #creating list to store vector representation of each abstract

for i in range(df.shape[0]):       #iterating through all abstract
    K=np.zeros([vector_size,1])    #creating empty array of size (vec_size,1) to add vector representation of each word
    count=0                        #creating count to check how many words are used from abstract
    
    for word in word_tokenize(df['Abstract'][i]):   #iterating through all words in given abstract

        if word in list(FastText.wv.index_to_key):      #if word exists in vocab , increase count by 1 and add array of given words in our defined array K

            count+=1
            K+=FastText.wv[word].reshape(vector_size,1)
    K=K/count                                        #taking average of given array
    K1.append(list(K))                               #appending vector of given abstract to the initial defined list
K1_array=np.array(K1)
K1_array=K1_array.reshape(df.shape[0],vector_size)   #converting into array of shape(no. of rows, vector_size)

# %% [markdown]
# ### Method 2

# %%
def get_mean_vector(word2vec_model, words):
    # remove out-of-vocabulary words
    words = [word for word in tokenize(words) if word in list(word2vec_model.wv.index_to_key)] #if word is in vocab 
    if len(words) >= 1:
        return np.mean(word2vec_model.wv[words], axis=0)
    else:
        return np.array([0]*100)

# %% [markdown]
# NB: Method 1 took time to run. Method 2 was prefered.

# %% [markdown]
# ### Abstract to vectors using skipgram Model

# %%
K1=[]                                     #defining empty list
for i in df.Abstract:
    K1.append(list(get_mean_vector(skipgram, i)))     #appending array to the list
    
    
K11=pd.DataFrame(K1).transpose()    # Saving vectors of each abstract in data frame so that we can use directly while running code again
K11.to_csv('skipgram-vec.csv')

# %%
K=pd.read_csv('skipgram-vec.csv')   #Loading our pretrained vectors of each abstract

skipgram_vectors=[]                          #transforming dataframe into required array like structure as we did in above step
for i in range(df.shape[0]):
    skipgram_vectors.append(K[str(i)].values)

# %% [markdown]
# ### For converting Title into vectors using skipgram

# %%
K1_title=[]
for i in df.Title:         #instead of abstract use title
    K1_title.append(list(get_mean_vector(skipgram, i)))    

    
K1_title=pd.DataFrame(K1).transpose()    # Saving vectors of each abstract in data frame so that we can use directly while running code again
K1_title.to_csv('skipgram-vec-title.csv')

# %%
K=pd.read_csv('skipgram-vec-title.csv')   #Loading our pretrained vectors of each abstract

K2_title=[]                          #transforming dataframe into required array like structure as we did in above step
for i in range(df.shape[0]):
    K2_title.append(K[str(i)].values)

# %% [markdown]
# ### Abstract to vector using FastText

# %%
K_fast=[]                                     #defining empty list
for i in df.Abstract:
    K_fast.append(list(get_mean_vector(FastText, i)))     #appending array to the list
    
K11=pd.DataFrame(K_fast).transpose()    # Saving vectors of each abstract in data frame so that we can use directly while running code again
K11.to_csv('FastText-vec.csv')

# %%
data=pd.read_csv('FastText-vec.csv')   #Loading our pretrained vectors of each abstract

fast_vectors=[]                          #transforming dataframe into required array like structure as we did in above step
for i in range(df.shape[0]):
    fast_vectors.append(data[str(i)].values)

# %% [markdown]
# # Cosine similarity function

# %%
#defining function to define cosine similarity

from numpy import dot
from numpy.linalg import norm

def cos_sim(a,b):

    return dot(a, b)/(norm(a)*norm(b))

# %% [markdown]
# # Input query Preprocessing

# %%
#Preprocessing input, because input should be in same form as training data set


def preprocessing_input(query,word2vec_model):
    query=preprocessing(query)
    query=query.replace('\n',' ')
    K=get_mean_vector(word2vec_model,query)
   
        
    return K

# %% [markdown]
# # Function to return 'n' similar results

# %%
pd.set_option("display.max_colwidth", None)  # Use None for unlimited column width

# %%
#function to return top n similar results

# where: 
#query - input query
# p - average vectors for all abs
#df1 - original

def top_n(query,p,df1,model):    
    print(query)
    
    query=preprocessing_input(query,model)    #preprocessing input to list of vectors
                                    
    x=[]
    #Converting cosine similarities of overall data set with input queries into LIST
    for i in range(len(p)):
        x.append(cos_sim(query,p[i]))
    
    
 #store list in tmp to retrieve index
    tmp=list(x)
    
 #sort list so that largest elements are on the far right
    
    res = sorted(range(len(x)), key = lambda sub: x[sub])[-5:]
    sim=[tmp[i] for i in reversed(res)]
    print(sim)
 #get index of the 10 or n largest element
    L=[]
    for i in reversed(res):
    
        L.append(i)
    return df1.iloc[L, [1,2,5,6]],sim     #returning dataframe (only id,title,abstract ,publication date)

# %%
#kidney
#breathing
#lung failure

# %% [markdown]
# ## Result Evaluation

# %%
# skipgram model

#Input your search query here

Query = "Kidney"

Results,sim = top_n(Query,skipgram_vectors,df1,skipgram)
Results
# Out:
# Kidney
# [0.8886441077074791, 0.7517497166297368, 0.7481830155393565, 0.740557859330261, 0.7375151638697638]
#                Trial ID  \
# 1984     2021-000412-28
# 3473     2020-001467-82
# 3071     2020-004951-34
# 10414  CHICTR2000030030
# 1543     2020-005416-22
#
#                                                                                                                                                                                                                                     Title  \
# 1984                                                                                                            COVID-19: Sars-Cov2 vaccination in kidney transplant patient: a phase IV study of the immunogenicity and its determinants
# 3473                                                                                     An Open-Label Study Evaluating Anti-Viral Effects of Voclosporin in SARS-CoV-2 Positive Kidney Transplant Recipients  the VOCOVID Study COVID-19
# 3071             Community participants with COPD or bronchiectasis and at risk of Respiratory Viral Infections including SARS-CoV-2: An open-label, multicentre feasibility study of an inhaled nitric oxide generating solution RESP301
# 10414                                                                                                                                      The risk factor and prognosis of acute kidney injury in novel coronavirus pneumonia (COVID-19)
# 1543   A Phase 3 Randomized, Double-Blind, Placebo-Controlled, Parallel Group, Multicenter Study Evaluating the Efficacy and Safety of Remdesivir in Participants with Severely Reduced Kidney Function who are Hospitalized for COVID-19
#
#                                                                                                                                                                                                    Abstract  \
# 1984                                                                                                                                                                             Kidney transplant patients
# 3473                                                                                                                                                   SARS-CoV-2 infection in Kidney Transplant Recipients
# 3071                                                                                                                                          Chronic obstructive pulmonary disease COPD and bronchiectasis
# 10414  To demonstrate the abnormal urine analysis and kidney impairment of COVID-19 paitients on admission.To  assess the incidence, risk facors and prognosis of acute kidney injury in COVID-19 patients.
# 1543                                                                                                                            Coronavirus disease 2019 COVID-19 in patients with chronic renal impairment
#
#       Publication date
# 1984        2021-01-26
# 3473        2020-10-23
# 3071        2020-11-27
# 10414       2020-02-01
# 1543        2021-03-24

# %%
# fasttext model

#Input your search query here

Query = "Virus"

Results,sim=top_n(Query,fast_vectors,df1,FastText)
Results
# Out:
# Virus
# [0.8256134750137379, 0.8132416216086437, 0.8043780230399123, 0.8020005067297569, 0.7777725116739161]
#             Trial ID  \
# 9917  2020-001162-12
# 4917  2020-002394-94
# 6073  2020-002106-68
# 9986  2020-001113-21
# 6172  2020-002027-10
#
#                                                                                                                                                                        Title  \
# 9917             An adaptive phase 3, randomized, double-blind, placebo-controlled, study assessing efficacy and safety of sarilumab for hospitalized patients with COVID-19
# 4917                                                      Pulsed, inhaled nitric oxide iNO for the treatment of patients with mild or moderate corona virus disease COVID-19
# 6073      Favipiravir, lopinavir/ritonavir or combination therapy: a randomised, double blind, 2x2 factorial placebo-controlled trial of early antiviral therapy in COVID-19
# 9986                                                                                                                      Randomised Evaluation of COVID-19 Therapy RECOVERY
# 6172  A prospective, multicenter, randomized PHASE II clinical trial of enzalutamide treatment to decrease the morbidity in patients with Corona virus disease 2019 COVID-19
#
#                                       Abstract Publication date
# 9917                    Corona virus infection       2020-03-26
# 4917                      Corona virus disease       2020-06-19
# 6073         SARS-CoV-2 Corona virus infection       2020-07-16
# 9986  COVID-19 infection with SARS-CoV-2 virus       2020-03-17
# 6172        Corona virus disease 2019 COVID-19       2020-05-13

# %% [markdown]
# # Streamlit App (Refer Medical.py file to run the app)

# %%
import streamlit as st
import plotly.graph_objects as go
import numpy as np

def main():
    # Load data and models
    data = df1  # DataFrame to display
    model = top_n  # Model to return n similar results

    # Set the title of the app
    st.title("🔬 Medical Search Engine")  # Title with an emoji

    # Custom description with markdown
    st.markdown("""
    **Welcome to the Medical Search Engine!**  
    Type your query in the search box below to find similar medical papers based on your input.
    """)
    
    # Search box with custom style
    user_input = st.text_input("🔍 Enter your search query:", placeholder="Search for medical studies...", key="search_input")

    # Add a progress bar or spinner to indicate processing
    if user_input:
        with st.spinner("Processing your query... Please wait."):
            # Fetch results using the model
            P, sim = model(str(user_input), K2, data)
        
        # Create a plotly table for the results
        fig = go.Figure(data=[go.Table(
            header=dict(values=['ID', 'Title', 'Abstract', 'Publication Date', 'Similarity'],
                        fill_color='lightgray', align='center'),
            cells=dict(values=[list(P['Trial ID'].values),
                               list(P['Title'].values),
                               list(P['Abstract'].values),
                               list(P['Publication date'].values),
                               list(np.around(sim, 4))],
                       fill_color='whitesmoke', align='center'))
        ])

        # Customize the table layout for better readability
        fig.update_layout(
            height=700,
            margin=dict(l=20, r=20, b=20, t=40),
            paper_bgcolor='rgb(245, 245, 245)',  # Light gray background
            title="Search Results",
            title_x=0.5,
            title_font=dict(size=20, family="Arial, sans-serif"),
        )

        # Display the results as a Plotly table
        st.plotly_chart(fig, use_container_width=True)

        # Add a footer with a link to a relevant resource (optional)
        st.markdown("---")
        st.markdown("[Learn more about medical research](https://www.ncbi.nlm.nih.gov)")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 58
#      55         st.markdown("[Learn more about medical research](https://www.ncbi.nlm.nih.gov)")
#      57 if __name__ == "__main__":
# ---> 58     main()
#
# Cell In[1], line 7, in main()
#       5 def main():
#       6     # Load data and models
# ----> 7     data = df1  # DataFrame to display
#       8     model = top_n  # Model to return n similar results
#      10     # Set the title of the app
#
# NameError: name 'df1' is not defined

# %%
#streamlit function 
def main():
    # Load data and models
    data = df1     #our data which we have to display
    model = top_n  #top_n model to return n similar results
    

    st.title("Medical Search engine")      #title of our app
    st.write('Type your query here')       #text below title

    # User search 
    user_input = st.text_input("Search box")   #getting input from user

   
    # Fetch results
    if user_input:
        
        P,sim =model(str(user_input),K2,data)     #storing our output dataframe in P
        #Plotly function to display our dataframe in form of plotly table
        fig = go.Figure(data=[go.Table(header=dict(values=['ID', 'Title','Abstract','Publication Date','Similarity Score']),cells=dict(values=[list(P['Trial ID'].values),list(P['Title'].values), list(P['Abstract'].values),list(P['Publication date'].values),list(np.around(sim,4))],align='center'))])
        #displying our plotly table
        fig.update_layout(height=1700) 
        st.plotly_chart(fig) 
        # Get individual results
    

if __name__ == "__main__":
    main()

# %%
# !pip freeze > requirements.txt
# Out:
# WARNING: Could not generate requirement for distribution -cikit-learn 0.21.3 (c:\programdata\anaconda3\lib\site-packages): Parse error at "'-cikit-l'": Expected W:(abcd...)
